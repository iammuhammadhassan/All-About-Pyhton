# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
df=pd.read_csv("Autism.csv")
df=pd.DataFrame(df)

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ... gender       ethnicity jundice austim  \
# 0         1         0          0  ...      f  White-European      no     no
# 1         1         0          1  ...      m          Latino      no    yes
# 2         1         1          1  ...      m          Latino     yes    yes
# 3         1         0          1  ...      f  White-European      no    yes
# 4         1         0          0  ...      f               ?      no     no
#
#      contry_of_res used_app_before result       age_desc relation Class/ASD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         704 non-null    int64
#  1   A2_Score         704 non-null    int64
#  2   A3_Score         704 non-null    int64
#  3   A4_Score         704 non-null    int64
#  4   A5_Score         704 non-null    int64
#  5   A6_Score         704 non-null    int64
#  6   A7_Score         704 non-null    int64
#  7   A8_Score         704 non-null    int64
#  8   A9_Score         704 non-null    int64
#  9   A10_Score        704 non-null    int64
#  10  age              704 non-null    object
#  11  gender           704 non-null    object
#  12  ethnicity        704 non-null    object
#  13  jundice          704 non-null    object
#  14  austim           704 non-null    object
#  15  contry_of_res    704 non-null    object
#  16  used_app_before  704 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                0
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                0
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
print(df[["gender","ethnicity"]])
# Out:
#     gender       ethnicity
# 0        f  White-European
# 1        m          Latino
# 2        m          Latino
# 3        f  White-European
# 4        f               ?
# ..     ...             ...
# 699      f  White-European
# 700      m        Hispanic
# 701      f               ?
# 702      m   'South Asian'
# 703      f  White-European
#
# [704 rows x 2 columns]

# %%
print(df)
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ... gender       ethnicity jundice austim  \
# ...

# %%
removing_columns = df.drop("jundice", axis=1)
print(removing_columns)
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score age gender       ethnicity austim  \
# ...

# %%
for i in df:
    print(i)
# Out:
# A1_Score
# A2_Score
# A3_Score
# A4_Score
# A5_Score
# A6_Score
# A7_Score
# A8_Score
# A9_Score
# A10_Score
# age
# gender
# ethnicity
# jundice
# austim
# contry_of_res
# used_app_before
# result
# age_desc
# relation
# Class/ASD

# %%
pakistan=df[df["contry_of_res"]=="Pakistan"]
print(pakistan)
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 41          0         0         0         0         1         1         0
# 659         1         1         1         1         1         1         0
# 702         1         0         0         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ... gender      ethnicity jundice austim  \
# 41          0         0          0  ...      f          Asian      no     no
# 659         0         1          1  ...      m              ?      no     no
# 702         0         1          1  ...      m  'South Asian'      no     no
#
#     contry_of_res used_app_before result       age_desc relation Class/ASD
# 41       Pakistan              no      2  '18 and more'     Self        NO
# 659      Pakistan              no      8  '18 and more'        ?       YES
# 702      Pakistan              no      6  '18 and more'     Self        NO
#
# [3 rows x 21 columns]

# %%
indian=df[df["contry_of_res"]=="India"]
print(indian)
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 100         0         1         1         0         0         0         0
# 103         1         1         0         0         1         0         1
# 104         0         0         0         0         1         1         0
# 105         0         0         0         0         0         0         0
# 108         1         0         0         1         1         1         1
# ..        ...       ...       ...       ...       ...       ...       ...
# 629         1         0         0         0         1         0         1
# 632         0         0         1         0         0         0         0
# 633         1         1         0         0         1         0         0
# 656         1         0         0         0         1         0         1
# 690         0         0         0         0         1         0         0
#
#      A8_Score  A9_Score  A10_Score  ... gender          ethnicity jundice  \
# ...

# %%
print(indian["Class/ASD"].value_counts())
print(pakistan["Class/ASD"].value_counts())
# Out:
# Class/ASD
# NO     75
# YES     6
# Name: count, dtype: int64
# Class/ASD
# NO     2
# YES    1
# Name: count, dtype: int64

# %%
plt.figure()
sns.countplot(x="Class/ASD", data=df)
plt.title("Distribution of Class/ASD")
# Out:
# Text(0.5, 1.0, 'Distribution of Class/ASD')

# %%
plt.figure()
plt.plot((df["contry_of_res"]=="Pakistan"), df["Class/ASD"], "o")
